# %%
import pandas as pd
pd.read_csv?

# %%
df = pd.DataFrame({'1stcolumn':[100,200], '2ndcolumn':[10,20]}) # this just creates a DataFrame for the example!
print('With the old column names:\n') # the \n makes a new line, so it's easier to see
print(df)

df.columns = ['FirstColumn','SecondColumn'] # rename the columns!
print('\n\nWith the new column names:\n')
print(df)
# Out:
# With the old column names:
#
#    1stcolumn  2ndcolumn
# 0        100         10
# 1        200         20
#
#
# With the new column names:
#
#    FirstColumn  SecondColumn
# 0          100            10
# 1          200            20

# %%
import matplotlib.pyplot as plt

# %%
surveys = pd.read_csv("C:\surveys.csv")

# %%
my_plot = surveys.plot("hindfoot_length", "weight", kind="scatter")

# %%
# %matplotlib inline

# %%
import numpy as np
sample_data = np.random.normal(0, 0.1, 1000)

# %%
plt.hist(sample_data)
# Out:
# (array([  3.,  28.,  69., 133., 242., 201., 191.,  92.,  33.,   8.]),
#  array([-0.30959686, -0.24897752, -0.18835819, -0.12773885, -0.06711951,
#         -0.00650018,  0.05411916,  0.11473849,  0.17535783,  0.23597717,
#          0.2965965 ]),
#  <a list of 10 Patch objects>)

# %%
fig, ax = plt.subplots()  # initiate an empty figure and axis matplotlib object
ax.hist(sample_data, 30)
# Out:
# (array([ 1.,  0.,  2.,  6., 11., 11., 16., 15., 38., 40., 34., 59., 74.,
#         77., 91., 75., 68., 58., 65., 74., 52., 37., 35., 20., 16., 11.,
#          6.,  3.,  4.,  1.]),
#  array([-0.30959686, -0.28939041, -0.26918397, -0.24897752, -0.22877108,
#         -0.20856463, -0.18835819, -0.16815174, -0.1479453 , -0.12773885,
#         -0.1075324 , -0.08732596, -0.06711951, -0.04691307, -0.02670662,
#         -0.00650018,  0.01370627,  0.03391271,  0.05411916,  0.0743256 ,
#          0.09453205,  0.11473849,  0.13494494,  0.15515138,  0.17535783,
#          0.19556427,  0.21577072,  0.23597717,  0.25618361,  0.27639006,
#          0.2965965 ]),
#  <a list of 30 Patch objects>)

# %%
fig, ax1 = plt.subplots() # prepare a matplotlib figure

surveys.plot("hindfoot_length", "weight", kind="scatter", ax=ax1)

# %%
myplot = (p9.ggplot(data=surveys,
                    mapping=p9.aes(x='hindfoot_length', y='weight')) +
              p9.geom_point())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9d64a01b6439> in <module>
# ----> 1 myplot = (p9.ggplot(data=surveys,
#       2                     mapping=p9.aes(x='hindfoot_length', y='weight')) +
#       3               p9.geom_point())
#
# NameError: name 'p9' is not defined

# %%
my_plt_version = myplot.draw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-fce64bbb06fa> in <module>
# ----> 1 my_plt_version = myplot.draw()
#
# NameError: name 'myplot' is not defined

# %%
p9_ax = my_plt_version.axes[0] # each subplot is an item in a list
p9_ax.set_xlabel("Hindfoot length")
p9_ax.tick_params(labelsize=16, pad=8)
p9_ax.set_title('Scatter plot of weight versus hindfoot length', fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5e8772c1c6be> in <module>
# ----> 1 p9_ax = my_plt_version.axes[0] # each subplot is an item in a list
#       2 p9_ax.set_xlabel("Hindfoot length")
#       3 p9_ax.tick_params(labelsize=16, pad=8)
#       4 p9_ax.set_title('Scatter plot of weight versus hindfoot length', fontsize=15)
#
# NameError: name 'my_plt_version' is not defined
